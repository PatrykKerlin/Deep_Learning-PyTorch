# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Math prerequisites
# ### LECTURE: Softmax
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202305

# %%
import matplotlib.pyplot as plt
# import libraries
import numpy as np
import torch
import torch.nn as nn

# %%
# "manually" in numpy

# the list of numbers
z = [1, 2, 3]

# compute the softmax result
num = np.exp(z)
denominator = np.sum(np.exp(z))
sigma = num / denominator

print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
# repeat with some random integers
z = np.random.randint(-5, high=15, size=25)
print(z)

# compute the softmax result
num = np.exp(z)
den = np.sum(num)
sigma = num / den

# compare
plt.plot(z, sigma, 'ko')
plt.xlabel('Original number (z)')
plt.ylabel('Softmaxified $\sigma$')
plt.yscale('log')
plt.title('$\sum\sigma$ = %g' % np.sum(sigma))
plt.show()
# Out:
# [13 14 10  2  8 -4  5  1  1  8  2 14 12 -4 -4  4  7 -5  4 13  6  2  6 -5
#  -2]

# %% [markdown]
# # Using pytorch

# %%
# slightly more involved using torch.nn

# create an instance of the softmax activation class
softmax = nn.Softmax(dim=0)

# then apply the data to that function
sigmaT = softmax(torch.Tensor(z))

# now we get the results
print(sigmaT)
# Out:
# tensor([1.2702e-01, 3.4528e-01, 6.3241e-03, 2.1215e-06, 8.5587e-04, 5.2586e-09,
#         4.2611e-05, 7.8045e-07, 7.8045e-07, 8.5587e-04, 2.1215e-06, 3.4528e-01,
#         4.6729e-02, 5.2586e-09, 5.2586e-09, 1.5676e-05, 3.1486e-04, 1.9345e-09,
#         1.5676e-05, 1.2702e-01, 1.1583e-04, 2.1215e-06, 1.1583e-04, 1.9345e-09,
#         3.8856e-08])

# %%
# show that they are the same
plt.plot(sigma, sigmaT, 'ko')
plt.xlabel('"Manual" softmax')
plt.ylabel('Pytorch nn.Softmax')
plt.title(f'The two methods correlate at r={np.corrcoef(sigma, sigmaT)[0, 1]}')
plt.show()
